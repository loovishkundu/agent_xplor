# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# Extract AWS Account ID from ARN\n\nHere's a solution to extract the AWS account ID from an ARN string:\n\n```python\ndef extract_account_id(arn):\n    \"\"\"\n    Extract AWS account ID from an ARN string.\n    \n    ARN format: arn:partition:service:region:account-id:resource-type/resource-id\n    \n    Args:\n        arn (str): The ARN string\n        \n    Returns:\n        str: The account ID, or empty string if not present\n    \"\"\"\n    parts = arn.split(':')\n    \n    # ARN structure: arn:partition:service:region:account-id:resource...\n    # Index:         0   1           2       3      4            5\n    if len(parts) >= 5:\n        account_id = parts[4]\n        return account_id if account_id else \"\"\n    return \"\"\n\n\n# Test cases\ntest_arns = [\n    'arn:aws:s3:::my-bucket/path/to/object',  # S3 (no account ID)\n    'arn:aws:iam::123456789012:user/username',  # IAM with account ID\n    'arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0',  # EC2\n    'arn:aws:lambda:us-west-2:987654321098:function:my-function',  # Lambda\n]\n\nfor arn in test_arns:\n    account_id = extract_account_id(arn)\n    print(f\"ARN: {arn}\")\n    print(f\"Account ID: {account_id if account_id else '(none)'}\\n\")\n```\n\n**Output:**\n```\nARN: arn:aws:s3:::my-bucket/path/to/object\nAccount ID: (none)\n\nARN: arn:aws:iam::123456789012:user/username\nAccount ID: 123456789012\n\nARN: arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0\nAccount ID: 123456789012\n\nARN: arn:aws:lambda:us-west-2:987654321098:function:my-function\nAccount ID: 987654321098\n```\n\n## Key Points:\n\n- **S3 bucket ARNs** don't have an account ID (the field is empty)\n- **Most other AWS resources** have account IDs in the 5th field (index 4)\n- The function returns an empty string if no account ID is present\n- You can validate the account ID is numeric (12 digits) if needed",
#     "test_case": {
#       "task": "Extract the AWS account ID from an ARN string like 'arn:aws:s3:::my-bucket/path/to/object'",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly solves the stated problem and demonstrates good understanding of ARN structure. The implementation is straightforward and the documentation is helpful. However, it lacks defensive programming practices such as input validation and error handling. For production use, the function should validate inputs, check account ID format (12 digits), and handle edge cases gracefully. The missing validation could lead to silent failures or exceptions depending on input quality."
#   },
#   {
#     "output": "# CloudFormation Template for S3 Bucket with Versioning and Public Access Block\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for S3 bucket with versioning enabled and public access blocked\",\n  \"Resources\": {\n    \"S3Bucket\": {\n      \"Type\": \"AWS::S3::Bucket\",\n      \"Properties\": {\n        \"BucketName\": {\n          \"Fn::Sub\": \"my-secure-bucket-${AWS::AccountId}\"\n        },\n        \"VersioningConfiguration\": {\n          \"Status\": \"Enabled\"\n        },\n        \"Tags\": [\n          {\n            \"Key\": \"Environment\",\n            \"Value\": \"Production\"\n          },\n          {\n            \"Key\": \"Purpose\",\n            \"Value\": \"Secure Data Storage\"\n          }\n        ]\n      }\n    },\n    \"S3BucketPublicAccessBlock\": {\n      \"Type\": \"AWS::S3::PublicAccessBlock\",\n      \"Properties\": {\n        \"BucketName\": {\n          \"Ref\": \"S3Bucket\"\n        },\n        \"BlockPublicAcls\": true,\n        \"BlockPublicPolicy\": true,\n        \"IgnorePublicAcls\": true,\n        \"RestrictPublicBuckets\": true\n      }\n    }\n  },\n  \"Outputs\": {\n    \"BucketName\": {\n      \"Description\": \"Name of the S3 bucket\",\n      \"Value\": {\n        \"Ref\": \"S3Bucket\"\n      },\n      \"Export\": {\n        \"Name\": {\n          \"Fn::Sub\": \"${AWS::StackName}-BucketName\"\n        }\n      }\n    },\n    \"BucketArn\": {\n      \"Description\": \"ARN of the S3 bucket\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"S3Bucket\",\n          \"Arn\"\n        ]\n      },\n      \"Export\": {\n        \"Name\": {\n          \"Fn::Sub\": \"${AWS::StackName}-BucketArn\"\n        }\n      }\n    }\n  }\n}\n```\n\n## Key Features:\n\n| Feature | Details |\n|---------|---------|\n| **Versioning** | Enabled to maintain object version history |\n| **Public Access Block** | All four settings enabled for maximum security |\n| **Unique Name** | Uses Account ID to ensure global uniqueness |\n| **Tags** | Included for resource organization |\n| **Outputs** | Exports bucket name and ARN for reference |\n\n## How to Deploy:\n\n```bash\naws cloudformation create-stack \\\n  --stack-name my-secure-s3-stack \\\n  --template-body file://template.json\n```\n\nThis template ensures your S3 bucket is secure by default with versioning enabled for data protection and all public access routes blocked.",
#     "test_case": {
#       "task": "Create a CloudFormation template JSON object for an S3 bucket with versioning enabled and public access blocked",
#       "format": "json"
#     },
#     "score": 8,
#     "reasoning": "The solution successfully fulfills the stated requirements with valid CloudFormation syntax and good fundamental practices. The template is production-ready and includes helpful extras like outputs and tags. However, it misses opportunities to strengthen security further through encryption configuration and could improve code robustness with explicit dependencies. The hardcoded values reduce reusability across different deployment scenarios."
#   },
#   {
#     "output": "# AWS S3 Bucket Name Validator\n\nHere's a comprehensive Python function that validates AWS S3 bucket names according to AWS naming rules:\n\n```python\nimport re\n\ndef is_valid_s3_bucket_name(bucket_name):\n    \"\"\"\n    Validates if a given string is a valid AWS S3 bucket name.\n    \n    AWS S3 bucket naming rules:\n    1. Bucket names must be between 3 and 63 characters long\n    2. Bucket names can consist only of lowercase letters, numbers, dots (.), and hyphens (-)\n    3. Bucket names must start and end with a letter or number\n    4. Bucket names cannot contain consecutive dots\n    5. Bucket names cannot be formatted as an IP address (e.g., 192.168.5.4)\n    6. Bucket names cannot start with \"xn--\"\n    7. Bucket names cannot end with \"-s3alias\"\n    \n    Args:\n        bucket_name (str): The bucket name to validate\n    \n    Returns:\n        bool: True if valid, False otherwise\n    \"\"\"\n    \n    # Check if input is a string\n    if not isinstance(bucket_name, str):\n        return False\n    \n    # Rule 1: Check length (3-63 characters)\n    if len(bucket_name) < 3 or len(bucket_name) > 63:\n        return False\n    \n    # Rule 2: Check allowed characters (lowercase letters, numbers, dots, hyphens)\n    if not re.match(r'^[a-z0-9.-]+$', bucket_name):\n        return False\n    \n    # Rule 3: Must start and end with letter or number\n    if not re.match(r'^[a-z0-9].*[a-z0-9]$', bucket_name):\n        # Handle edge case of single character (which we already excluded by length rule)\n        if len(bucket_name) == 1:\n            return bucket_name.isalnum() and bucket_name.islower()\n        return False\n    \n    # Rule 4: Cannot contain consecutive dots\n    if '..' in bucket_name:\n        return False\n    \n    # Rule 5: Cannot be formatted as an IP address\n    if re.match(r'^(\\d{1,3}\\.){3}\\d{1,3}$', bucket_name):\n        return False\n    \n    # Rule 6: Cannot start with \"xn--\"\n    if bucket_name.startswith('xn--'):\n        return False\n    \n    # Rule 7: Cannot end with \"-s3alias\"\n    if bucket_name.endswith('-s3alias'):\n        return False\n    \n    return True\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        # Valid bucket names\n        (\"my-bucket\", True),\n        (\"mybucket123\", True),\n        (\"my.bucket.name\", True),\n        (\"test-bucket-123\", True),\n        (\"a\", False),  # Too short\n        (\"ab\", False),  # Too short\n        (\"abc\", True),  # Minimum valid length\n        \n        # Invalid - length\n        (\"a\" * 64, False),  # Too long\n        \n        # Invalid - uppercase letters\n        (\"MyBucket\", False),\n        (\"MYBUCKET\", False),\n        \n        # Invalid - special characters\n        (\"my_bucket\", False),\n        (\"my bucket\", False),\n        (\"my@bucket\", False),\n        \n        # Invalid - starts/ends with dot or hyphen\n        (\".mybucket\", False),\n        (\"mybucket.\", False),\n        (\"-mybucket\", False),\n        (\"mybucket-\", False),\n        \n        # Invalid - consecutive dots\n        (\"my..bucket\", False),\n        \n        # Invalid - IP address format\n        (\"192.168.1.1\", False),\n        (\"10.0.0.1\", False),\n        \n        # Invalid - starts with xn--\n        (\"xn--mybucket\", False),\n        \n        # Invalid - ends with -s3alias\n        (\"mybucket-s3alias\", False),\n        \n        # Edge cases\n        (\"123\", True),  # Valid: numbers only\n        ",
#     "test_case": {
#       "task": "Write a Python function that validates if a given string is a valid AWS S3 bucket name according to AWS naming rules",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly implements AWS S3 bucket naming rules with good code quality and documentation. The validation logic is sound for the core requirements. However, the submission has a critical flaw: the test cases code is incomplete and won't execute, which undermines confidence in the solution's correctness. Additionally, minor edge cases in regex patterns and IP validation exist, though they have limited practical impact given AWS's other constraints."
#   }
# ]
